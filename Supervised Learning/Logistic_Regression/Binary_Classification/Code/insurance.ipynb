# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../CSV/insurance.csv")
df
# Out:
#     age  have_insurance
# 0    22               0
# 1    25               0
# 2    47               1
# 3    52               0
# 4    46               1
# 5    56               1
# 6    55               0
# 7    60               1
# 8    62               1
# 9    61               1
# 10   18               0
# 11   28               0
# 12   27               0
# 13   29               0
# 14   49               1
# 15   55               1
# 16   25               1
# 17   58               1
# 18   19               0
# 19   18               0
# 20   21               0
# 21   26               0
# 22   40               1
# 23   45               1
# 24   50               1
# 25   54               1
# 26   23               0

# %%
X = df['age']
X
# Out:
# 0     22
# 1     25
# 2     47
# 3     52
# 4     46
# 5     56
# 6     55
# 7     60
# 8     62
# 9     61
# 10    18
# 11    28
# 12    27
# 13    29
# 14    49
# 15    55
# 16    25
# 17    58
# 18    19
# 19    18
# 20    21
# 21    26
# 22    40
# 23    45
# 24    50
# 25    54
# 26    23
# Name: age, dtype: int64

# %%
Y = df.have_insurance
Y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     1
# 6     0
# 7     1
# 8     1
# 9     1
# 10    0
# 11    0
# 12    0
# 13    0
# 14    1
# 15    1
# 16    1
# 17    1
# 18    0
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    1
# 25    1
# 26    0
# Name: have_insurance, dtype: int64

# %%
plt.xlabel("age")
plt.ylabel("have_insurance")
plt.scatter(X,Y,color='red',marker='+')

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df[['age']],df.have_insurance,train_size=0.9)

# %%
X_test
# Out:
#     age
# 23   45
# 19   18
# 10   18

# %%
X_train
# Out:
#     age
# 11   28
# 20   21
# 17   58
# 24   50
# 21   26
# 26   23
# 13   29
# 3    52
# 2    47
# 14   49
# 22   40
# 6    55
# 18   19
# 1    25
# 9    61
# 0    22
# 4    46
# 7    60
# 16   25
# 12   27
# 5    56
# 8    62
# 15   55
# 25   54

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 0, 0])

# %%
X_test
# Out:
#     age
# 23   45
# 19   18
# 10   18

# %%
Y_test
# Out:
# 23    1
# 19    0
# 10    0
# Name: have_insurance, dtype: int64

# %%
model.score(X_test, Y_test)
# Out:
# 1.0

# %%
model.predict_proba(X_test)
# Out:
# array([[0.32548293, 0.67451707],
#        [0.93793299, 0.06206701],
#        [0.93793299, 0.06206701]])

# %%
model.predict([[25]])
# Out:
# C:\Users\Joel\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])
